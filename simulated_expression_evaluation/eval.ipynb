# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://maksobelser:Novogeslo2@transvae.xf2fzdd.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# List all databases for the client
databases = client.list_database_names()
print(databases)
# Out:
# ['seml', 'admin', 'local']

# %%
db = client['seml']
collections = db.list_collection_names()
print(collections)
# Out:
# ['fs.files', 'trans_VAE_extra', 'transVAE_baseline', 'fs.chunks']

# %%
collection = db["transVAE_baseline"]
documents = collection.find() 
configs = []
results = []
dbd_h = []
dbd_OOD= []
mSTZ_h = []
mSTZ_OOD = []
for document in documents:
    if "result" not in document.keys() or document["result"] is None:
        break
    configs.append(document["config"])
    dbd_h.append(document["result"]["r2_dbdb_healthy"]["value"])
    dbd_OOD.append(document["result"]["r2_dbdb_OOD"]["value"])
    mSTZ_h.append(document["result"]["r2_mSTZ_healthy"]["value"])
    mSTZ_OOD.append(document["result"]["r2_mSTZ_OOD"]["value"])

# %%
import pandas as pd

# %%
results_df = pd.DataFrame(configs)

# %%
results_df["r2_dbdb_healthy"] = dbd_h
results_df["r2_dbdb_OOD"] = dbd_OOD
results_df["r2_mSTZ_healthy"] = mSTZ_h
results_df["r2_mSTZ_OOD"] = mSTZ_OOD

# %%
results_df.to_csv("intermediate_results.csv")

# %%
pd.set_option('display.max_rows', 200)

# %%
results_df.columns

# %%
results_df.sort_values(by = "r2_dbdb_healthy", ascending=False)[['cov_embed_dims', 'dropout_rate', 'kl_weight', 'learning_rate', 'max_epochs', 'n_hidden','n_latent', 'n_layers', 'seed', 'r2_dbdb_healthy', 'r2_dbdb_OOD','r2_mSTZ_healthy', 'r2_mSTZ_OOD']]

# %% [markdown]
# ### Failed experiments

# %%
from tqdm import tqdm

# %%
collection = db["transVAE_baseline"]
documents = collection.find() 
failed_configs = []
for document in tqdm(documents, total = 240 + 84):
    if "result" not in document.keys() or document["result"] is None:
        failed_configs.append(document["config"])
# Out:
# 100%|██████████| 324/324 [10:25<00:00,  1.93s/it]

# %%
failed = pd.DataFrame(failed_configs)

# %%
len(failed)
# Out:
# 84

# %%
failed
# Out:
#     overwrite      db_collection  cov_embed_dims  \
# 0         114  transVAE_baseline              10
# 1         120  transVAE_baseline              10
# 2         126  transVAE_baseline              10
# 3         127  transVAE_baseline              10
# 4         133  transVAE_baseline              10
# 5         139  transVAE_baseline              10
# 6         148  transVAE_baseline              10
# 7         154  transVAE_baseline              10
# 8         160  transVAE_baseline              10
# 9         165  transVAE_baseline              10
# 10        171  transVAE_baseline              10
# 11        177  transVAE_baseline              10
# 12        199  transVAE_baseline              10
# 13        200  transVAE_baseline              10
# 14        205  transVAE_baseline              10
# 15        206  transVAE_baseline              10
# 16        211  transVAE_baseline              10
# 17        212  transVAE_baseline              10
# 18        235  transVAE_baseline              10
# 19        236  transVAE_baseline              10
# 20        237  transVAE_baseline              10
# 21        239  transVAE_baseline              10
# 22        240  transVAE_baseline              10
# 23        241  transVAE_baseline              10
# 24        242  transVAE_baseline              10
# 25        243  transVAE_baseline              10
# 26        245  transVAE_baseline              10
# 27        246  transVAE_baseline              10
# 28        247  transVAE_baseline              10
# 29        248  transVAE_baseline              10
# 30        249  transVAE_baseline              10
# 31        251  transVAE_baseline              10
# 32        252  transVAE_baseline              10
# 33        254  transVAE_baseline              10
# 34        255  transVAE_baseline              10
# 35        260  transVAE_baseline              10
# 36        261  transVAE_baseline              10
# 37        266  transVAE_baseline              10
# 38        267  transVAE_baseline              10
# 39        271  transVAE_baseline              10
# 40        272  transVAE_baseline              10
# 41        273  transVAE_baseline              10
# 42        274  transVAE_baseline              10
# 43        275  transVAE_baseline              10
# 44        276  transVAE_baseline              10
# 45        277  transVAE_baseline              10
# 46        278  transVAE_baseline              10
# 47        279  transVAE_baseline              10
# 48        280  transVAE_baseline              10
# 49        281  transVAE_baseline              10
# 50        282  transVAE_baseline              10
# 51        283  transVAE_baseline              10
# 52        284  transVAE_baseline              10
# 53        285  transVAE_baseline              10
# 54        286  transVAE_baseline              10
# 55        287  transVAE_baseline              10
# 56        288  transVAE_baseline              10
# 57        292  transVAE_baseline              10
# 58        293  transVAE_baseline              10
# 59        294  transVAE_baseline              10
# 60        298  transVAE_baseline              10
# 61        299  transVAE_baseline              10
# 62        300  transVAE_baseline              10
# 63        304  transVAE_baseline              10
# 64        305  transVAE_baseline              10
# 65        306  transVAE_baseline              10
# 66        307  transVAE_baseline              10
# 67        308  transVAE_baseline              10
# 68        309  transVAE_baseline              10
# 69        310  transVAE_baseline              10
# 70        311  transVAE_baseline              10
# 71        312  transVAE_baseline              10
# 72        313  transVAE_baseline              10
# 73        314  transVAE_baseline              10
# 74        315  transVAE_baseline              10
# 75        316  transVAE_baseline              10
# 76        317  transVAE_baseline              10
# 77        318  transVAE_baseline              10
# 78        319  transVAE_baseline              10
# 79        320  transVAE_baseline              10
# 80        321  transVAE_baseline              10
# 81        322  transVAE_baseline              10
# 82        323  transVAE_baseline              10
# 83        324  transVAE_baseline              10
#
#                           dataset_ground_truth1  \
# 0   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 1   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 2   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 3   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 4   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 5   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 6   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 7   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 8   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 9   dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 10  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 11  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 12  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 13  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 14  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 15  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 16  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 17  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 18  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 19  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 20  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 21  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 22  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 23  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 24  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 25  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 26  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 27  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 28  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 29  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 30  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 31  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 32  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 33  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 34  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 35  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 36  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 37  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 38  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 39  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 40  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 41  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 42  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 43  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 44  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 45  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 46  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 47  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 48  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 49  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 50  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 51  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 52  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 53  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 54  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 55  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 56  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 57  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 58  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 59  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 60  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 61  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 62  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 63  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 64  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 65  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 66  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 67  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 68  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 69  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 70  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 71  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 72  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 73  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 74  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 75  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 76  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 77  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 78  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 79  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 80  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 81  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 82  dbdb_ground_truth_top3000_baseline_hvg.h5ad
# 83  dbdb_ground_truth_top3000_baseline_hvg.h5ad
#
#                           dataset_ground_truth2  \
# 0   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 1   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 2   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 3   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 4   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 5   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 6   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 7   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 8   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 9   mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 10  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 11  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 12  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 13  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 14  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 15  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 16  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 17  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 18  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 19  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 20  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 21  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 22  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 23  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 24  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 25  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 26  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 27  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 28  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 29  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 30  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 31  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 32  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 33  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 34  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 35  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 36  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 37  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 38  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 39  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 40  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 41  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 42  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 43  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 44  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 45  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 46  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 47  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 48  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 49  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 50  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 51  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 52  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 53  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 54  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 55  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 56  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 57  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 58  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 59  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 60  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 61  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 62  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 63  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 64  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 65  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 66  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 67  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 68  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 69  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 70  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 71  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 72  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 73  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 74  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 75  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 76  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 77  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 78  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 79  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 80  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 81  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 82  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
# 83  mSTZ_ground_truth_top3000_baseline_hvg.h5ad
#
#                            dataset_to_predict  \
# 0   Wang_to_predict_top3000_baseline_hvg.h5ad
# 1   Wang_to_predict_top3000_baseline_hvg.h5ad
# 2   Wang_to_predict_top3000_baseline_hvg.h5ad
# 3   Wang_to_predict_top3000_baseline_hvg.h5ad
# 4   Wang_to_predict_top3000_baseline_hvg.h5ad
# 5   Wang_to_predict_top3000_baseline_hvg.h5ad
# 6   Wang_to_predict_top3000_baseline_hvg.h5ad
# 7   Wang_to_predict_top3000_baseline_hvg.h5ad
# 8   Wang_to_predict_top3000_baseline_hvg.h5ad
# 9   Wang_to_predict_top3000_baseline_hvg.h5ad
# 10  Wang_to_predict_top3000_baseline_hvg.h5ad
# 11  Wang_to_predict_top3000_baseline_hvg.h5ad
# 12  Wang_to_predict_top3000_baseline_hvg.h5ad
# 13  Wang_to_predict_top3000_baseline_hvg.h5ad
# 14  Wang_to_predict_top3000_baseline_hvg.h5ad
# 15  Wang_to_predict_top3000_baseline_hvg.h5ad
# 16  Wang_to_predict_top3000_baseline_hvg.h5ad
# 17  Wang_to_predict_top3000_baseline_hvg.h5ad
# 18  Wang_to_predict_top3000_baseline_hvg.h5ad
# 19  Wang_to_predict_top3000_baseline_hvg.h5ad
# 20  Wang_to_predict_top3000_baseline_hvg.h5ad
# 21  Wang_to_predict_top3000_baseline_hvg.h5ad
# 22  Wang_to_predict_top3000_baseline_hvg.h5ad
# 23  Wang_to_predict_top3000_baseline_hvg.h5ad
# 24  Wang_to_predict_top3000_baseline_hvg.h5ad
# 25  Wang_to_predict_top3000_baseline_hvg.h5ad
# 26  Wang_to_predict_top3000_baseline_hvg.h5ad
# 27  Wang_to_predict_top3000_baseline_hvg.h5ad
# 28  Wang_to_predict_top3000_baseline_hvg.h5ad
# 29  Wang_to_predict_top3000_baseline_hvg.h5ad
# 30  Wang_to_predict_top3000_baseline_hvg.h5ad
# 31  Wang_to_predict_top3000_baseline_hvg.h5ad
# 32  Wang_to_predict_top3000_baseline_hvg.h5ad
# 33  Wang_to_predict_top3000_baseline_hvg.h5ad
# 34  Wang_to_predict_top3000_baseline_hvg.h5ad
# 35  Wang_to_predict_top3000_baseline_hvg.h5ad
# 36  Wang_to_predict_top3000_baseline_hvg.h5ad
# 37  Wang_to_predict_top3000_baseline_hvg.h5ad
# 38  Wang_to_predict_top3000_baseline_hvg.h5ad
# 39  Wang_to_predict_top3000_baseline_hvg.h5ad
# 40  Wang_to_predict_top3000_baseline_hvg.h5ad
# 41  Wang_to_predict_top3000_baseline_hvg.h5ad
# 42  Wang_to_predict_top3000_baseline_hvg.h5ad
# 43  Wang_to_predict_top3000_baseline_hvg.h5ad
# 44  Wang_to_predict_top3000_baseline_hvg.h5ad
# 45  Wang_to_predict_top3000_baseline_hvg.h5ad
# 46  Wang_to_predict_top3000_baseline_hvg.h5ad
# 47  Wang_to_predict_top3000_baseline_hvg.h5ad
# 48  Wang_to_predict_top3000_baseline_hvg.h5ad
# 49  Wang_to_predict_top3000_baseline_hvg.h5ad
# 50  Wang_to_predict_top3000_baseline_hvg.h5ad
# 51  Wang_to_predict_top3000_baseline_hvg.h5ad
# 52  Wang_to_predict_top3000_baseline_hvg.h5ad
# 53  Wang_to_predict_top3000_baseline_hvg.h5ad
# 54  Wang_to_predict_top3000_baseline_hvg.h5ad
# 55  Wang_to_predict_top3000_baseline_hvg.h5ad
# 56  Wang_to_predict_top3000_baseline_hvg.h5ad
# 57  Wang_to_predict_top3000_baseline_hvg.h5ad
# 58  Wang_to_predict_top3000_baseline_hvg.h5ad
# 59  Wang_to_predict_top3000_baseline_hvg.h5ad
# 60  Wang_to_predict_top3000_baseline_hvg.h5ad
# 61  Wang_to_predict_top3000_baseline_hvg.h5ad
# 62  Wang_to_predict_top3000_baseline_hvg.h5ad
# 63  Wang_to_predict_top3000_baseline_hvg.h5ad
# 64  Wang_to_predict_top3000_baseline_hvg.h5ad
# 65  Wang_to_predict_top3000_baseline_hvg.h5ad
# 66  Wang_to_predict_top3000_baseline_hvg.h5ad
# 67  Wang_to_predict_top3000_baseline_hvg.h5ad
# 68  Wang_to_predict_top3000_baseline_hvg.h5ad
# 69  Wang_to_predict_top3000_baseline_hvg.h5ad
# 70  Wang_to_predict_top3000_baseline_hvg.h5ad
# 71  Wang_to_predict_top3000_baseline_hvg.h5ad
# 72  Wang_to_predict_top3000_baseline_hvg.h5ad
# 73  Wang_to_predict_top3000_baseline_hvg.h5ad
# 74  Wang_to_predict_top3000_baseline_hvg.h5ad
# 75  Wang_to_predict_top3000_baseline_hvg.h5ad
# 76  Wang_to_predict_top3000_baseline_hvg.h5ad
# 77  Wang_to_predict_top3000_baseline_hvg.h5ad
# 78  Wang_to_predict_top3000_baseline_hvg.h5ad
# 79  Wang_to_predict_top3000_baseline_hvg.h5ad
# 80  Wang_to_predict_top3000_baseline_hvg.h5ad
# 81  Wang_to_predict_top3000_baseline_hvg.h5ad
# 82  Wang_to_predict_top3000_baseline_hvg.h5ad
# 83  Wang_to_predict_top3000_baseline_hvg.h5ad
#
#                            dataset_train  dropout_rate  kl_weight  \
# 0   train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 1   train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 2   train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 3   train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 4   train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 5   train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 6   train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 7   train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 8   train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 9   train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 10  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 11  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 12  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 13  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 14  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 15  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 16  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 17  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 18  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 19  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 20  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 21  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 22  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 23  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 24  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 25  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 26  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 27  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 28  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 29  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 30  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 31  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 32  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 33  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 34  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 35  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 36  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 37  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 38  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 39  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 40  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 41  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 42  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 43  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 44  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 45  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 46  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 47  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 48  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 49  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 50  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 51  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 52  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 53  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 54  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 55  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 56  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 57  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 58  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 59  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 60  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 61  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 62  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 63  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 64  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 65  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 66  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 67  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 68  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 69  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 70  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 71  train_adata_baseline_top3000hvg.h5ad           0.1      0.005
# 72  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 73  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 74  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 75  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 76  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 77  train_adata_baseline_top3000hvg.h5ad           0.2      0.005
# 78  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 79  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 80  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 81  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 82  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
# 83  train_adata_baseline_top3000hvg.h5ad           0.3      0.005
#
#     learning_rate  max_epochs  n_hidden  n_latent  n_layers  seed
# 0           0.005         500       800       512         5    44
# 1           0.005         500       800       512         5    44
# 2           0.005         500       800       512         5    44
# 3           0.005         500       800       256        10    42
# 4           0.005         500       800       256        10    42
# 5           0.005         500       800       256        10    42
# 6           0.005         500      1000       512         5    42
# 7           0.005         500      1000       512         5    42
# 8           0.005         500      1000       512         5    42
# 9           0.005         500      1000       256        10    44
# 10          0.005         500      1000       256        10    44
# 11          0.005         500      1000       256        10    44
# 12          0.005         500      1200       256        10    42
# 13          0.005         500      1200       256        10    43
# 14          0.005         500      1200       256        10    42
# 15          0.005         500      1200       256        10    43
# 16          0.005         500      1200       256        10    42
# 17          0.005         500      1200       256        10    43
# 18          0.010         500       800       256        10    42
# 19          0.010         500       800       256        10    43
# 20          0.010         500       800       256        10    44
# 21          0.010         500       800       512        10    43
# 22          0.010         500       800       512        10    44
# 23          0.010         500       800       256        10    42
# 24          0.010         500       800       256        10    43
# 25          0.010         500       800       256        10    44
# 26          0.010         500       800       512        10    43
# 27          0.010         500       800       512        10    44
# 28          0.010         500       800       256        10    42
# 29          0.010         500       800       256        10    43
# 30          0.010         500       800       256        10    44
# 31          0.010         500       800       512        10    43
# 32          0.010         500       800       512        10    44
# 33          0.010         500      1000       256         5    43
# 34          0.010         500      1000       256         5    44
# 35          0.010         500      1000       256         5    43
# 36          0.010         500      1000       256         5    44
# 37          0.010         500      1000       256         5    43
# 38          0.010         500      1000       256         5    44
# 39          0.010         500      1000       256        10    42
# 40          0.010         500      1000       256        10    43
# 41          0.010         500      1000       256        10    44
# 42          0.010         500      1000       512        10    42
# 43          0.010         500      1000       512        10    43
# 44          0.010         500      1000       512        10    44
# 45          0.010         500      1000       256        10    42
# 46          0.010         500      1000       256        10    43
# 47          0.010         500      1000       256        10    44
# 48          0.010         500      1000       512        10    42
# 49          0.010         500      1000       512        10    43
# 50          0.010         500      1000       512        10    44
# 51          0.010         500      1000       256        10    42
# 52          0.010         500      1000       256        10    43
# 53          0.010         500      1000       256        10    44
# 54          0.010         500      1000       512        10    42
# 55          0.010         500      1000       512        10    43
# 56          0.010         500      1000       512        10    44
# 57          0.010         500      1200       512         5    42
# 58          0.010         500      1200       512         5    43
# 59          0.010         500      1200       512         5    44
# 60          0.010         500      1200       512         5    42
# 61          0.010         500      1200       512         5    43
# 62          0.010         500      1200       512         5    44
# 63          0.010         500      1200       512         5    42
# 64          0.010         500      1200       512         5    43
# 65          0.010         500      1200       512         5    44
# 66          0.010         500      1200       256        10    42
# 67          0.010         500      1200       256        10    43
# 68          0.010         500      1200       256        10    44
# 69          0.010         500      1200       512        10    42
# 70          0.010         500      1200       512        10    43
# 71          0.010         500      1200       512        10    44
# 72          0.010         500      1200       256        10    42
# 73          0.010         500      1200       256        10    43
# 74          0.010         500      1200       256        10    44
# 75          0.010         500      1200       512        10    42
# 76          0.010         500      1200       512        10    43
# 77          0.010         500      1200       512        10    44
# 78          0.010         500      1200       256        10    42
# 79          0.010         500      1200       256        10    43
# 80          0.010         500      1200       256        10    44
# 81          0.010         500      1200       512        10    42
# 82          0.010         500      1200       512        10    43
# 83          0.010         500      1200       512        10    44
