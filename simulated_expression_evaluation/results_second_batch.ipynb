# %%
import seml
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.set_option('display.max_rows', 300)

# %%
results = seml.get_results('transVAE_baseline_corrected', to_data_frame=True)
# Out:
# ...
#   0%|          | 0/156 [00:00<?, ?it/s]

# %%
plt.scatter(results["result.r2_dbdb_healthy"], results["result.r2_dbdb_OOD"])

# %%
results.columns
# Out:
# Index(['_id', 'config.overwrite', 'config.db_collection',
#        'config.cov_embed_dims', 'config.dataset_ground_truth1',
#        'config.dataset_ground_truth2', 'config.dataset_to_predict',
#        'config.dataset_train', 'config.dropout_rate', 'config.kl_weight',
#        'config.learning_rate', 'config.max_epochs', 'config.n_hidden',
#        'config.n_latent', 'config.n_layers', 'config.save_folder_name',
#        'config.seed', 'result.kl_weight', 'result.train_loss_step',
#        'result.train_loss_epoch', 'result.elbo_train',
#        'result.reconstruction_loss_train', 'result.kl_local_train',
#        'result.kl_global_train', 'result.r2_dbdb_healthy',
#        'result.r2_dbdb_OOD', 'result.r2_mSTZ_healthy', 'result.r2_mSTZ_OOD'],
#       dtype='object')

# %%
results.sort_values(by="result.r2_mSTZ_OOD", ascending=False)#[['config.dataset_train', 'config.dropout_rate', 'config.kl_weight', "config.n_hidden",
                                                             #  'config.learning_rate', 'config.max_epochs', 'config.n_hidden','config.n_latent', 'config.n_layers', 
                                                             #  'config.save_folder_name', 'config.seed',"result.r2_dbdb_healthy", "result.r2_dbdb_OOD", 
                                                             #  "result.r2_mSTZ_healthy", "result.r2_mSTZ_OOD"]]
# Out:
#      _id  config.overwrite         config.db_collection  \
# 132  144               144  transVAE_baseline_corrected
# 131  143               143  transVAE_baseline_corrected
# 154  214               214  transVAE_baseline_corrected
# 155  215               215  transVAE_baseline_corrected
# 137  158               158  transVAE_baseline_corrected
# 146  179               179  transVAE_baseline_corrected
# 139  165               165  transVAE_baseline_corrected
# 145  177               177  transVAE_baseline_corrected
# 121  125               125  transVAE_baseline_corrected
# 136  156               156  transVAE_baseline_corrected
# 92    93                93  transVAE_baseline_corrected
# 30    31                31  transVAE_baseline_corrected
# 150  204               204  transVAE_baseline_corrected
# 106  107               107  transVAE_baseline_corrected
# 100  101               101  transVAE_baseline_corrected
# 117  121               121  transVAE_baseline_corrected
# ...
